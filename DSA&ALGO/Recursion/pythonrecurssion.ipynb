# %%
def facto(n):
    if n == 0: # this is the base value
        return 1
    return n * facto(n-1) # and this is the final statment

# %%
n = int(input())
facto(n)
# Out:
# 2800
# ...

# %% [markdown]
# ## here the limit of recurssion in my computer is around 2850
